# %% [markdown]
# <a href="https://colab.research.google.com/github/imrazack-cisco/bits/blob/main/BOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Your Webex Access Token
access_token = 'MTU2MjA4YjctMTNlNi00YjkwLTk2YWEtYjAzNDUzZDg4MTBkMmNjNDZkZjItNGU0_PF84_1eb65fdf-9643-417f-9974-ad72cae0e10f'

# List of direct reportees' emails
reportees = [
'imrazack@cisco.com',
'ramakk@cisco.com',
'shpingil@cisco.com',
'saiamrut@cisco.com',
'prateupa@cisco.com',
'raklokes@cisco.com',
'gpairait@cisco.com',
'mbora@cisco.com',
'naushaid@cisco.com',
'akumars4@cisco.com',
'gsodha@cisco.com',
'nipushar@cisco.com',
'vkichann@cisco.com',
'anshiyad@cisco.com',
'haripnat@cisco.com',
'rosm@cisco.com',
'pradhal@cisco.com',
'kijayapa@cisco.com',
'laraja@cisco.com',
'sarucham@cisco.com',
'renjithg@cisco.com',
'gsaminat@cisco.com',
'rkumara3@cisco.com',
'araamana@cisco.com',
'sunilkt@cisco.com',
'johnvarg@cisco.com',
'sgachchi@cisco.com',
'apvijaya@cisco.com',
'faafridi@cisco.com',
'arsadana@cisco.com',
'anechakr@cisco.com',
'ver2@cisco.com',
'aargarg@cisco.com',
'arinbhat@cisco.com',
'sivyas@cisco.com',
'psivanat@cisco.com',
'jeagrawa@cisco.com',
'aikotha@cisco.com',
'avasharm@cisco.com',
'ramyanai@cisco.com',
'nkumarm@cisco.com',
'vishnuve@cisco.com',
'yyohadha@cisco.com',
'arpdash@cisco.com',
'vselvar2@cisco.com',
'kishank@cisco.com',
'paponnus@cisco.com',
'shreyaj2@cisco.com',
'rruhi@cisco.com',
'ajamshed@cisco.com',
'gagayatr@cisco.com',
'pvema@cisco.com',
'srajandh@cisco.com',
'lokmanoh@cisco.com',
'vrmehrot@cisco.com',
'uekbote@cisco.com',
'shchoube@cisco.com',
'parisang@cisco.com',
'ashissah@cisco.com',
'hthirumu@cisco.com',
'bdevi@cisco.com',
'sakhilla@cisco.com',
'dtamiri@cisco.com',
'ayuanand@cisco.com',
'kalraja@cisco.com',
'nikiraje@cisco.com',
'gurnatar@cisco.com',
'pra2@cisco.com',
'sppriyad@cisco.com',
'tjanarda@cisco.com',
'shubhsin@cisco.com',
'jaslebha@cisco.com',
'tmaram@cisco.com',
'pprabhun@cisco.com',
'ashaban@cisco.com',
'akatare@cisco.com',
'srmb@cisco.com',
'supvanam@cisco.com',
'karsethi@cisco.com',
'haramesh@cisco.com',
'ramym@cisco.com',
'sanandy@cisco.com',
'aditghos@cisco.com',
'sohhegde@cisco.com',
'nikichav@cisco.com',
'sbarhanp@cisco.com',
'parulmoz@cisco.com',
'karmuth2@cisco.com',
'gakula@cisco.com',
'sesap@cisco.com',
]

# Your message
message = "Hello, \n\nShare your Performance Reflections by today itself in workday , any issues/challenges , please discuss with your manager. \n\nPlease ping imrazack@cisco.com on webex teams once done. \n\n Thanks Imran Razack"

# API endpoint for sending messages
url = 'https://webexapis.com/v1/messages'

# Send message to each reportee
for email in reportees:
    headers = {
        'Authorization': f'Bearer {access_token}',
        'Content-Type': 'application/json'
    }

    payload = {
        'toPersonEmail': email,
        'text': message
    }

    response = requests.post(url, json=payload, headers=headers)
    if response.status_code == 200:
        print(f'Message sent to {email}')
    else:
        # This line was not indented correctly, causing the IndentationError
        print(f'Failed to send message to {email}: {response.status_code}, {response.text}')
# Out:
# Message sent to imrazack@cisco.com
# Message sent to ramakk@cisco.com
# Message sent to shpingil@cisco.com
# Message sent to saiamrut@cisco.com
# Message sent to prateupa@cisco.com
# Message sent to raklokes@cisco.com
# Message sent to gpairait@cisco.com
# Message sent to mbora@cisco.com
# Message sent to naushaid@cisco.com
# Message sent to akumars4@cisco.com
# Message sent to gsodha@cisco.com
# Message sent to krvishwa@cisco.com
# Message sent to pkamal@cisco.com
# Message sent to nipushar@cisco.com
# Message sent to vkichann@cisco.com
# Message sent to sanysach@cisco.com
# Message sent to anshiyad@cisco.com
# Message sent to haripnat@cisco.com
# Message sent to rosm@cisco.com
# Message sent to pradhal@cisco.com
# Message sent to kijayapa@cisco.com
# Message sent to laraja@cisco.com
# Message sent to sarucham@cisco.com
# Message sent to renjithg@cisco.com
# Message sent to gsaminat@cisco.com
# Message sent to gaaverma@cisco.com
# Message sent to rkumara3@cisco.com
# ...
